# %%
import cv2
import matplotlib.pyplot as plt

# %%
img=cv2.imread('checkerboard_18x18.png')

# %%
img.shape

# %%
plt.imshow(img)

# %%
img1=cv2.imread('coca-cola-logo.png')

# %%
img1.shape
# Out:
# (700, 700, 3)

# %%
plt.imshow(img1[:,:,::-1])

# %%
img2.shape

# %%
img2=cv2.imread('coca-cola-logo.png',0)
plt.imshow(img2,cmap='gray')
